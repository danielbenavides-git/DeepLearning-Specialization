# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy
from PIL import Image
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.python.framework import ops
from cnn_utils import *
from test_utils_CNN import summary, comparator

# %matplotlib inline
np.random.seed(1)

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_happy_dataset()

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %%
index = 120
plt.imshow(X_train_orig[index]) #display sample training image
plt.show()

# %%
# GRADED FUNCTION: happyModel

def happyModel():
    """
    Implements the forward propagation for the binary classification model:
    ZEROPAD2D -> CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code all the values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    None

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """
    model = tf.keras.Sequential([
            ## ZeroPadding2D with padding 3, input shape of 64 x 64 x 3
        
            ## Conv2D with 32 7x7 filters and stride of 1
            
            ## BatchNormalization for axis 3
            
            ## ReLU
            
            ## Max Pooling 2D with default parameters
            
            ## Flatten layer
            
            ## Dense layer with 1 unit for output & 'sigmoid' activation
            
            # YOUR CODE STARTS HERE
            
            tfl.ZeroPadding2D(padding=(3, 3), input_shape=(64, 64, 3)),
            tfl.Conv2D(filters=32, kernel_size=(7, 7), strides=(1, 1), padding='valid', activation='linear'),
            tfl.BatchNormalization(axis=3),
            tfl.ReLU(),
            tfl.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'),
            tfl.Flatten(),
            tfl.Dense(units=1, activation='sigmoid')
            
            # YOUR CODE ENDS HERE
        ])
    
    return model

# %%
happy_model = happyModel()

happy_model.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])
# Out:
# c:\Users\Daniel Benavides\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\reshaping\zero_padding2d.py:72: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
happy_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ zero_padding2d (ZeroPadding2D)  │ (None, 70, 70, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 64, 64, 32)     │         4,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │        32,769 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 37,633 (147.00 KB)
#  Trainable params: 37,569 (146.75 KB)
#  Non-trainable params: 64 (256.00 B)

# %%
happy_model.fit(X_train, Y_train, epochs=10, batch_size=16)
# Out:
# Epoch 1/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5816 - loss: 1.9973
# Epoch 2/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9091 - loss: 0.2230
# Epoch 3/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9383 - loss: 0.1940
# Epoch 4/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9771 - loss: 0.1036
# Epoch 5/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9691 - loss: 0.0852
# Epoch 6/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9373 - loss: 0.1671
# Epoch 7/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9617 - loss: 0.0964
# Epoch 8/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9420 - loss: 0.1722
# Epoch 9/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9840 - loss: 0.0536
# Epoch 10/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9409 - loss: 0.1652

# %%
happy_model.evaluate(X_test, Y_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.6564 - loss: 1.2682
# [1.2932777404785156, 0.6266666650772095]

# %%
# SIGNS DATASET
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_signs_dataset()

# %%
# Example of an image from the dataset
index = 4
plt.imshow(X_train_orig[index])
print ("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 2

# %%
X_train = X_train_orig/255.
X_test = X_test_orig/255.
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %%
# GRADED FUNCTION: convolutional_model

def convolutional_model(input_shape):
    """
    Implements the forward propagation for the model:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code some values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    input_img -- input dataset, of shape (input_shape)

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """

    input_img = tf.keras.Input(shape=input_shape)
    ## CONV2D: 8 filters 4x4, stride of 1, padding 'SAME'
    # Z1 = None
    ## RELU
    # A1 = None
    ## MAXPOOL: window 8x8, stride 8, padding 'SAME'
    # P1 = None
    ## CONV2D: 16 filters 2x2, stride 1, padding 'SAME'
    # Z2 = None
    ## RELU
    # A2 = None
    ## MAXPOOL: window 4x4, stride 4, padding 'SAME'
    # P2 = None
    ## FLATTEN
    # F = None
    ## Dense layer
    ## 6 neurons in output layer. Hint: one of the arguments should be "activation='softmax'" 
    # outputs = None
    # YOUR CODE STARTS HERE
    
    Z1 = tfl.Conv2D(filters=8, kernel_size=(4, 4), strides=(1, 1), padding='same')(input_img)
    A1 = tfl.ReLU()(Z1)
    P1 = tfl.MaxPooling2D(pool_size=(8, 8), strides=(8, 8), padding='same')(A1)

    Z2 = tfl.Conv2D(filters=16, kernel_size=(2, 2), strides=(1, 1), padding='same')(P1)
    A2 = tfl.ReLU()(Z2)
    P2 = tfl.MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same')(A2)
    F = tfl.Flatten()(P2)

    outputs = tfl.Dense(units=6, activation='softmax')(F)
    
    # YOUR CODE ENDS HERE
    model = tf.keras.Model(inputs=input_img, outputs=outputs)
    return model

# %%
conv_model = convolutional_model((64, 64, 3))
conv_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
conv_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 8)      │           392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 64, 64, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 16)       │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 8, 8, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,310 (5.12 KB)
#  Trainable params: 1,310 (5.12 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train)).batch(64)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test)).batch(64)
history = conv_model.fit(train_dataset, epochs=100, validation_data=test_dataset)
# Out:
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.1397 - loss: 1.8134 - val_accuracy: 0.1667 - val_loss: 1.7873
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1669 - loss: 1.7892 - val_accuracy: 0.2500 - val_loss: 1.7812
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2401 - loss: 1.7821 - val_accuracy: 0.2417 - val_loss: 1.7787
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2504 - loss: 1.7777 - val_accuracy: 0.3333 - val_loss: 1.7745
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2785 - loss: 1.7727 - val_accuracy: 0.3667 - val_loss: 1.7684
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3176 - loss: 1.7665 - val_accuracy: 0.3833 - val_loss: 1.7625
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3699 - loss: 1.7591 - val_accuracy: 0.4083 - val_loss: 1.7551
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3835 - loss: 1.7497 - val_accuracy: 0.4083 - val_loss: 1.7462
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3880 - loss: 1.7363 - val_accuracy: 0.4333 - val_loss: 1.7322
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4061 - loss: 1.7186 - val_accuracy: 0.4667 - val_loss: 1.7145
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4108 - loss: 1.6933 - val_accuracy: 0.5000 - val_loss: 1.6902
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4457 - loss: 1.6592 - val_accuracy: 0.5250 - val_loss: 1.6576
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4739 - loss: 1.6166 - val_accuracy: 0.5000 - val_loss: 1.6232
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5011 - loss: 1.5681 - val_accuracy: 0.5083 - val_loss: 1.5814
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5280 - loss: 1.5127 - val_accuracy: 0.5250 - val_loss: 1.5312
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5574 - loss: 1.4515 - val_accuracy: 0.5250 - val_loss: 1.4790
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5835 - loss: 1.3938 - val_accuracy: 0.5333 - val_loss: 1.4313
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5935 - loss: 1.3373 - val_accuracy: 0.5167 - val_loss: 1.3784
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6115 - loss: 1.2859 - val_accuracy: 0.5333 - val_loss: 1.3329
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6142 - loss: 1.2412 - val_accuracy: 0.5417 - val_loss: 1.2856
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6221 - loss: 1.2021 - val_accuracy: 0.5500 - val_loss: 1.2469
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6288 - loss: 1.1647 - val_accuracy: 0.6000 - val_loss: 1.2085
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6353 - loss: 1.1315 - val_accuracy: 0.6000 - val_loss: 1.1756
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6459 - loss: 1.0979 - val_accuracy: 0.6167 - val_loss: 1.1397
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6504 - loss: 1.0673 - val_accuracy: 0.6333 - val_loss: 1.1058
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6662 - loss: 1.0379 - val_accuracy: 0.6500 - val_loss: 1.0779
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6793 - loss: 1.0121 - val_accuracy: 0.6750 - val_loss: 1.0487
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6757 - loss: 0.9839 - val_accuracy: 0.6833 - val_loss: 1.0229
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6937 - loss: 0.9642 - val_accuracy: 0.6833 - val_loss: 0.9989
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6965 - loss: 0.9385 - val_accuracy: 0.6917 - val_loss: 0.9766
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6987 - loss: 0.9175 - val_accuracy: 0.7000 - val_loss: 0.9542
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6996 - loss: 0.8967 - val_accuracy: 0.7083 - val_loss: 0.9347
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7055 - loss: 0.8778 - val_accuracy: 0.6917 - val_loss: 0.9148
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7080 - loss: 0.8582 - val_accuracy: 0.6833 - val_loss: 0.8966
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7105 - loss: 0.8420 - val_accuracy: 0.6917 - val_loss: 0.8792
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7144 - loss: 0.8242 - val_accuracy: 0.7167 - val_loss: 0.8622
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7221 - loss: 0.8090 - val_accuracy: 0.7167 - val_loss: 0.8454
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7258 - loss: 0.7924 - val_accuracy: 0.7167 - val_loss: 0.8302
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7291 - loss: 0.7783 - val_accuracy: 0.7333 - val_loss: 0.8154
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7321 - loss: 0.7631 - val_accuracy: 0.7333 - val_loss: 0.8009
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7335 - loss: 0.7496 - val_accuracy: 0.7500 - val_loss: 0.7881
# Epoch 42/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7362 - loss: 0.7361 - val_accuracy: 0.7583 - val_loss: 0.7746
# Epoch 43/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7440 - loss: 0.7226 - val_accuracy: 0.7500 - val_loss: 0.7628
# Epoch 44/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7468 - loss: 0.7106 - val_accuracy: 0.7583 - val_loss: 0.7519
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7527 - loss: 0.6980 - val_accuracy: 0.7583 - val_loss: 0.7413
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7585 - loss: 0.6867 - val_accuracy: 0.7583 - val_loss: 0.7312
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7633 - loss: 0.6757 - val_accuracy: 0.7583 - val_loss: 0.7204
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7658 - loss: 0.6647 - val_accuracy: 0.7583 - val_loss: 0.7111
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7771 - loss: 0.6547 - val_accuracy: 0.7500 - val_loss: 0.7012
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7835 - loss: 0.6443 - val_accuracy: 0.7583 - val_loss: 0.6914
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7832 - loss: 0.6346 - val_accuracy: 0.7500 - val_loss: 0.6817
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7879 - loss: 0.6251 - val_accuracy: 0.7583 - val_loss: 0.6737
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7930 - loss: 0.6158 - val_accuracy: 0.7583 - val_loss: 0.6652
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7912 - loss: 0.6067 - val_accuracy: 0.7667 - val_loss: 0.6560
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7974 - loss: 0.5983 - val_accuracy: 0.7750 - val_loss: 0.6494
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7996 - loss: 0.5894 - val_accuracy: 0.7750 - val_loss: 0.6408
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8004 - loss: 0.5811 - val_accuracy: 0.7917 - val_loss: 0.6315
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8083 - loss: 0.5737 - val_accuracy: 0.7750 - val_loss: 0.6250
# Epoch 59/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8085 - loss: 0.5656 - val_accuracy: 0.7833 - val_loss: 0.6168
# Epoch 60/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8185 - loss: 0.5571 - val_accuracy: 0.7917 - val_loss: 0.6093
# Epoch 61/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8196 - loss: 0.5496 - val_accuracy: 0.7917 - val_loss: 0.6018
# Epoch 62/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8238 - loss: 0.5418 - val_accuracy: 0.7917 - val_loss: 0.5946
# Epoch 63/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8288 - loss: 0.5340 - val_accuracy: 0.8000 - val_loss: 0.5873
# Epoch 64/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8294 - loss: 0.5263 - val_accuracy: 0.8000 - val_loss: 0.5805
# Epoch 65/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8325 - loss: 0.5190 - val_accuracy: 0.8000 - val_loss: 0.5739
# Epoch 66/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8385 - loss: 0.5118 - val_accuracy: 0.8000 - val_loss: 0.5671
# Epoch 67/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8399 - loss: 0.5047 - val_accuracy: 0.8000 - val_loss: 0.5611
# Epoch 68/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8452 - loss: 0.4975 - val_accuracy: 0.8167 - val_loss: 0.5549
# Epoch 69/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8472 - loss: 0.4911 - val_accuracy: 0.8167 - val_loss: 0.5491
# Epoch 70/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8510 - loss: 0.4844 - val_accuracy: 0.8167 - val_loss: 0.5432
# Epoch 71/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8499 - loss: 0.4782 - val_accuracy: 0.8167 - val_loss: 0.5376
# Epoch 72/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8549 - loss: 0.4719 - val_accuracy: 0.8167 - val_loss: 0.5320
# Epoch 73/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8613 - loss: 0.4659 - val_accuracy: 0.8167 - val_loss: 0.5271
# Epoch 74/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8635 - loss: 0.4599 - val_accuracy: 0.8167 - val_loss: 0.5217
# Epoch 75/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8650 - loss: 0.4544 - val_accuracy: 0.8333 - val_loss: 0.5174
# Epoch 76/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8686 - loss: 0.4485 - val_accuracy: 0.8333 - val_loss: 0.5121
# Epoch 77/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8702 - loss: 0.4432 - val_accuracy: 0.8333 - val_loss: 0.5072
# Epoch 78/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8722 - loss: 0.4378 - val_accuracy: 0.8333 - val_loss: 0.5022
# Epoch 79/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8772 - loss: 0.4326 - val_accuracy: 0.8333 - val_loss: 0.4975
# Epoch 80/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8772 - loss: 0.4271 - val_accuracy: 0.8333 - val_loss: 0.4926
# Epoch 81/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8789 - loss: 0.4223 - val_accuracy: 0.8333 - val_loss: 0.4878
# Epoch 82/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8789 - loss: 0.4170 - val_accuracy: 0.8333 - val_loss: 0.4835
# Epoch 83/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8804 - loss: 0.4124 - val_accuracy: 0.8333 - val_loss: 0.4788
# Epoch 84/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8804 - loss: 0.4075 - val_accuracy: 0.8333 - val_loss: 0.4742
# Epoch 85/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8813 - loss: 0.4029 - val_accuracy: 0.8333 - val_loss: 0.4704
# Epoch 86/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8820 - loss: 0.3983 - val_accuracy: 0.8250 - val_loss: 0.4661
# Epoch 87/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8820 - loss: 0.3938 - val_accuracy: 0.8333 - val_loss: 0.4623
# Epoch 88/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8843 - loss: 0.3895 - val_accuracy: 0.8500 - val_loss: 0.4585
# Epoch 89/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8842 - loss: 0.3852 - val_accuracy: 0.8583 - val_loss: 0.4550
# Epoch 90/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8864 - loss: 0.3810 - val_accuracy: 0.8583 - val_loss: 0.4513
# Epoch 91/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8852 - loss: 0.3769 - val_accuracy: 0.8583 - val_loss: 0.4482
# Epoch 92/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8897 - loss: 0.3728 - val_accuracy: 0.8583 - val_loss: 0.4444
# Epoch 93/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8905 - loss: 0.3689 - val_accuracy: 0.8500 - val_loss: 0.4410
# Epoch 94/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8905 - loss: 0.3649 - val_accuracy: 0.8500 - val_loss: 0.4376
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8905 - loss: 0.3612 - val_accuracy: 0.8500 - val_loss: 0.4343
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8919 - loss: 0.3573 - val_accuracy: 0.8500 - val_loss: 0.4307
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8924 - loss: 0.3536 - val_accuracy: 0.8500 - val_loss: 0.4275
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8939 - loss: 0.3500 - val_accuracy: 0.8500 - val_loss: 0.4245
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8952 - loss: 0.3463 - val_accuracy: 0.8500 - val_loss: 0.4215
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8959 - loss: 0.3426 - val_accuracy: 0.8500 - val_loss: 0.4184

# %%
history.history
# Out:
# {'accuracy': [0.14629629254341125,
#   0.1935185194015503,
#   0.24722221493721008,
#   0.27222222089767456,
#   0.2768518626689911,
#   0.3083333373069763,
#   0.3629629611968994,
#   0.3777777850627899,
#   0.39629629254341125,
#   0.41203704476356506,
#   0.4148148000240326,
#   0.442592591047287,
#   0.46203702688217163,
#   0.4870370328426361,
#   0.5138888955116272,
#   0.5472221970558167,
#   0.5611110925674438,
#   0.5768518447875977,
#   0.5935184955596924,
#   0.5981481671333313,
#   0.6083333492279053,
#   0.6166666746139526,
#   0.6231481432914734,
#   0.6361111402511597,
#   0.644444465637207,
#   0.6620370149612427,
#   0.6777777671813965,
#   0.6787037253379822,
#   0.6925926208496094,
#   0.6990740895271301,
#   0.7046296000480652,
#   0.7064814567565918,
#   0.7111111283302307,
#   0.7175925970077515,
#   0.7212963104248047,
#   0.7240740656852722,
#   0.7324073910713196,
#   0.7361111044883728,
#   0.7435185313224792,
#   0.7462962865829468,
#   0.7509258985519409,
#   0.7555555701255798,
#   0.7629629373550415,
#   0.7657407522201538,
#   0.7740740776062012,
#   0.7768518328666687,
#   0.7814815044403076,
#   0.7851851582527161,
#   0.7907407283782959,
#   0.8009259104728699,
#   0.800000011920929,
#   0.8083333373069763,
#   0.8111110925674438,
#   0.8129629492759705,
#   0.8194444179534912,
#   0.824999988079071,
#   0.8240740895271301,
#   0.8296296000480652,
#   0.8314814567565918,
#   0.8379629850387573,
#   0.8398148417472839,
#   0.8416666388511658,
#   0.8435184955596924,
#   0.8444444537162781,
#   0.8462963104248047,
#   0.8509259223937988,
#   0.8527777791023254,
#   0.8574073910713196,
#   0.8592592477798462,
#   0.8611111044883728,
#   0.8601852059364319,
#   0.8638888597488403,
#   0.8685185313224792,
#   0.8703703880310059,
#   0.8703703880310059,
#   0.8740741014480591,
#   0.8759258985519409,
#   0.8787037134170532,
#   0.8824074268341064,
#   0.8824074268341064,
#   0.8833333253860474,
#   0.8833333253860474,
#   0.885185182094574,
#   0.885185182094574,
#   0.8861111402511597,
#   0.8888888955116272,
#   0.8888888955116272,
#   0.8916666507720947,
#   0.8907407522201538,
#   0.8935185074806213,
#   0.8925926089286804,
#   0.8962963223457336,
#   0.8981481194496155,
#   0.8981481194496155,
#   0.8981481194496155,
#   0.8990740776062012,
#   0.8999999761581421,
#   0.9009259343147278,
#   0.9018518328666687,
#   0.9027777910232544],
#  'loss': [1.8040084838867188,
#   1.7870182991027832,
#   1.7819712162017822,
#   1.777761697769165,
#   1.7724947929382324,
#   1.7660338878631592,
#   1.7582844495773315,
#   1.7480981349945068,
#   1.7335721254348755,
#   1.7145062685012817,
#   1.6879656314849854,
#   1.6528496742248535,
#   1.6106116771697998,
#   1.5626065731048584,
#   1.5077415704727173,
#   1.4483366012573242,
#   1.394635558128357,
#   1.3387222290039062,
#   1.2905285358428955,
#   1.2455552816390991,
#   1.208078145980835,
#   1.1710658073425293,
#   1.1363662481307983,
#   1.1026067733764648,
#   1.0717674493789673,
#   1.0432974100112915,
#   1.014158844947815,
#   0.9871705174446106,
#   0.9649737477302551,
#   0.9388951659202576,
#   0.9175460934638977,
#   0.8954059481620789,
#   0.8754773139953613,
#   0.8552407622337341,
#   0.837714672088623,
#   0.8192934393882751,
#   0.8034104108810425,
#   0.7860997915267944,
#   0.7711775302886963,
#   0.7553790211677551,
#   0.7415595054626465,
#   0.7274947166442871,
#   0.7141278982162476,
#   0.701364278793335,
#   0.6889991760253906,
#   0.6773124933242798,
#   0.6661067605018616,
#   0.65473872423172,
#   0.6445587873458862,
#   0.6338667273521423,
#   0.6240915656089783,
#   0.6143080592155457,
#   0.605073869228363,
#   0.5961621999740601,
#   0.5872229933738708,
#   0.5782091021537781,
#   0.5696954131126404,
#   0.5623156428337097,
#   0.5539040565490723,
#   0.5454456210136414,
#   0.537877082824707,
#   0.5300700664520264,
#   0.5222169160842896,
#   0.5145648121833801,
#   0.5071476697921753,
#   0.5001168251037598,
#   0.492991179227829,
#   0.4860232174396515,
#   0.4794957935810089,
#   0.47290006279945374,
#   0.4666373133659363,
#   0.46034669876098633,
#   0.4542582631111145,
#   0.4484880268573761,
#   0.44266805052757263,
#   0.4369552433490753,
#   0.43143439292907715,
#   0.42622503638267517,
#   0.42093610763549805,
#   0.41577258706092834,
#   0.4107981026172638,
#   0.4056221544742584,
#   0.4009636640548706,
#   0.39616572856903076,
#   0.3914484679698944,
#   0.3868449330329895,
#   0.3824140429496765,
#   0.3780287504196167,
#   0.37369975447654724,
#   0.36944565176963806,
#   0.3652972877025604,
#   0.3613068461418152,
#   0.3573888838291168,
#   0.35346928238868713,
#   0.3497895300388336,
#   0.34598132967948914,
#   0.3422062397003174,
#   0.3386298716068268,
#   0.335006445646286,
#   0.33151760697364807],
#  'val_accuracy': [0.1666666716337204,
#   0.25,
#   0.24166665971279144,
#   0.3333333432674408,
#   0.36666667461395264,
#   0.38333332538604736,
#   0.40833333134651184,
#   0.40833333134651184,
#   0.4333333373069763,
#   0.46666666865348816,
#   0.5,
#   0.5249999761581421,
#   0.5,
#   0.5083333253860474,
#   0.5249999761581421,
#   0.5249999761581421,
#   0.5333333611488342,
#   0.5166666507720947,
#   0.5333333611488342,
#   0.5416666865348816,
#   0.550000011920929,
#   0.6000000238418579,
#   0.6000000238418579,
#   0.6166666746139526,
#   0.6333333253860474,
#   0.6499999761581421,
#   0.675000011920929,
#   0.6833333373069763,
#   0.6833333373069763,
#   0.6916666626930237,
#   0.699999988079071,
#   0.7083333134651184,
#   0.6916666626930237,
#   0.6833333373069763,
#   0.6916666626930237,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7333333492279053,
#   0.7333333492279053,
#   0.75,
#   0.7583333253860474,
#   0.75,
#   0.7583333253860474,
#   0.7583333253860474,
#   0.7583333253860474,
#   0.7583333253860474,
#   0.7583333253860474,
#   0.75,
#   0.7583333253860474,
#   0.75,
#   0.7583333253860474,
#   0.7583333253860474,
#   0.7666666507720947,
#   0.7749999761581421,
#   0.7749999761581421,
#   0.7916666865348816,
#   0.7749999761581421,
#   0.7833333611488342,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.800000011920929,
#   0.800000011920929,
#   0.800000011920929,
#   0.800000011920929,
#   0.800000011920929,
#   0.8166666626930237,
#   0.8166666626930237,
#   0.8166666626930237,
#   0.8166666626930237,
#   0.8166666626930237,
#   0.8166666626930237,
#   0.8166666626930237,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.8333333134651184,
#   0.824999988079071,
#   0.8333333134651184,
#   0.8500000238418579,
#   0.8583333492279053,
#   0.8583333492279053,
#   0.8583333492279053,
#   0.8583333492279053,
#   0.8500000238418579,
#   0.8500000238418579,
#   0.8500000238418579,
#   0.8500000238418579,
#   0.8500000238418579,
#   0.8500000238418579,
#   0.8500000238418579,
#   0.8500000238418579],
#  'val_loss': [1.7873493432998657,
#   1.781150460243225,
#   1.7787455320358276,
#   1.7745163440704346,
#   1.768424153327942,
#   1.7624766826629639,
#   1.7551071643829346,
#   1.7462265491485596,
#   1.732178807258606,
#   1.714495301246643,
#   1.6901967525482178,
#   1.657588243484497,
#   1.62320077419281,
#   1.581431269645691,
#   1.531181812286377,
#   1.4789549112319946,
#   1.4313255548477173,
#   1.3784085512161255,
#   1.3328689336776733,
#   1.2855521440505981,
#   1.2469388246536255,
#   1.2085026502609253,
#   1.175646424293518,
#   1.13972806930542,
#   1.105783462524414,
#   1.077888011932373,
#   1.0487427711486816,
#   1.0229092836380005,
#   0.998914897441864,
#   0.9766063690185547,
#   0.9542496800422668,
#   0.934704065322876,
#   0.9147643446922302,
#   0.8965523838996887,
#   0.8792155385017395,
#   0.8622151613235474,
#   0.8454020023345947,
#   0.8302135467529297,
#   0.8154105544090271,
#   0.800868809223175,
#   0.7881337404251099,
#   0.7746476531028748,
#   0.7627704739570618,
#   0.7519035935401917,
#   0.7412648797035217,
#   0.7311800718307495,
#   0.7203500270843506,
#   0.7110577821731567,
#   0.7012320756912231,
#   0.6914188265800476,
#   0.6816599369049072,
#   0.6737242341041565,
#   0.6651546359062195,
#   0.655988872051239,
#   0.6493697762489319,
#   0.6407533288002014,
#   0.6315258145332336,
#   0.6250448822975159,
#   0.6168468594551086,
#   0.6093147397041321,
#   0.6018478870391846,
#   0.594629168510437,
#   0.5872913599014282,
#   0.5805423855781555,
#   0.5738966464996338,
#   0.5671409964561462,
#   0.5611333250999451,
#   0.5548855066299438,
#   0.54906165599823,
#   0.5431835055351257,
#   0.5376449227333069,
#   0.531998872756958,
#   0.5270867943763733,
#   0.5217427611351013,
#   0.5173543691635132,
#   0.5120507478713989,
#   0.5072416663169861,
#   0.5021690726280212,
#   0.4975489377975464,
#   0.4925919771194458,
#   0.48776766657829285,
#   0.4834561049938202,
#   0.47875988483428955,
#   0.4741831123828888,
#   0.4703959822654724,
#   0.46611568331718445,
#   0.46232324838638306,
#   0.4585059881210327,
#   0.4550497233867645,
#   0.45130863785743713,
#   0.4481629729270935,
#   0.44441065192222595,
#   0.4410330355167389,
#   0.4375714361667633,
#   0.4343229830265045,
#   0.4307115375995636,
#   0.4275399446487427,
#   0.42449456453323364,
#   0.42151281237602234,
#   0.41837775707244873]}

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 
df_loss_acc = pd.DataFrame(history.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
df_loss.plot(title='Model loss',figsize=(10,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(10,8)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# C:\Users\Daniel Benavides\AppData\Local\Temp\ipykernel_22792\162880813.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# C:\Users\Daniel Benavides\AppData\Local\Temp\ipykernel_22792\162880813.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Accuracy')]
